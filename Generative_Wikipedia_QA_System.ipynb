# %% [markdown]
# # Generative Wikipedia QA System
#
# This Colab notebook implements a small-scale generative QA system that answers user questions about machine learning topics using crawled Wikipedia content. The system combines semantic retrieval with a generative language model (Flan-T5) to synthesize coherent, context-rich answers. It includes modules for web crawling, text preprocessing, semantic indexing with SentenceTransformers and FAISS, and answer generation using Hugging Face Transformers.

# %% [markdown]
# #Imports & Helper Functions

# %%
# !pip install --upgrade pip
# !pip install "transformers<5.0.0" sentence-transformers requests beautifulsoup4 scikit-learn accelerate wordninja faiss-cpu nltk
# !pip install nltk
import os, json, time, unicodedata, wordninja
from datetime import datetime
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urlunparse, urljoin
import requests, nltk
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
import numpy as np
import torch
import faiss
from nltk.tokenize import sent_tokenize
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.1.1)
# Requirement already satisfied: transformers<5.0.0 in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: wordninja in /usr/local/lib/python3.11/dist-packages (2.0.0)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.11/dist-packages (1.11.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers<5.0.0) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers<5.0.0) (4.13.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
def demash_text(text):
    out = []
    for tok in text.split():
        pieces = wordninja.split(tok)
        out.append(" ".join(pieces) if len(pieces) > 1 else tok)
    return " ".join(out)

# %%
def safe_sent_tokenize(text):
    try:
        return sent_tokenize(text)
    except LookupError:
        nltk.download('punkt')
        return sent_tokenize(text)

# %%
def clean_text(text):
    # Remove weird characters, normalize, filter empty lines
    text = unicodedata.normalize("NFKC", text)
    text = text.replace("\n", " ").replace("\xa0", " ").strip()
    sentences = safe_sent_tokenize(text)
    return ". ".join(s for s in sentences if len(s) > 10 and "[" not in s)

# %%
def chunk_paragraphs(text, max_len=500):
    paras = [p.strip() for p in text.split("\n") if len(p.strip()) > 50]
    return [clean_text(p[:max_len]) for p in paras if len(p) > 50]

# %%
def normalize_url(url):
    p = urlparse(url)
    clean = p._replace(params="", query="", fragment="")
    norm = urlunparse(clean)
    return norm[:-1] if norm.endswith("/") else norm

# %%
def is_valid_en_wiki(url):
    p = urlparse(url)
    return p.scheme in ("http", "https") and p.netloc == "en.wikipedia.org" and p.path.startswith("/wiki/")

# %% [markdown]
# #Crawler

# %%
# English-only crawler with metadata
def crawl(start_url, max_depth=1, max_pages=2500, delay=1.0, visited=None):
    if visited is None:
        visited = set()
    seed = normalize_url(start_url)
    if not is_valid_en_wiki(seed):
        raise ValueError("Seed must be en.wikipedia.org/wiki/...")

    to_visit = [(seed, 0)]
    data = []
    while to_visit and len(visited) < max_pages:
        url, depth = to_visit.pop(0)
        if url in visited or depth > max_depth:
            continue
        print(f"Crawling: {url} (depth {depth})")
        try:
            resp = requests.get(url, timeout=10)
            if 'text/html' not in resp.headers.get('Content-Type', ''):
                continue
            soup = BeautifulSoup(resp.text, 'html.parser')
            title = soup.title.string if soup.title else ""
            paras = soup.find_all("p")
            page_paragraphs = chunk_paragraphs(" ".join(p.get_text() for p in paras))

            for i, para in enumerate(page_paragraphs):
                data.append({
                    "url": url,
                    "title": title,
                    "paragraph_id": i,
                    "depth": depth,
                    "fetched_at": datetime.utcnow().isoformat() + "Z",
                    "text": para
                })

            visited.add(url)
            for link in soup.find_all('a', href=True):
                raw = urljoin(url, link['href'])
                norm = normalize_url(raw)

                # Skip non-content pages (meta, file, help, etc.)
                if any(part in norm for part in [
                    "Special:", "Wikipedia:", "Help:", "Talk:", "File:",
                    "Template:", "Portal:", "Category:"
                ]):
                    continue

                if is_valid_en_wiki(norm) and norm not in visited:
                    to_visit.append((norm, depth + 1))

            time.sleep(delay)
        except Exception as e:
            print(f"[Error crawling {url}]: {e}")
    return data, visited

# %%
# Crawl seeds (cap=2500 pages) & save JSON
seeds = [
    "https://en.wikipedia.org/wiki/Machine_learning",
    "https://en.wikipedia.org/wiki/Deep_learning",
    "https://en.wikipedia.org/wiki/Transformer_(machine_learning_model)",
    "https://en.wikipedia.org/wiki/Supervised_learning",
    "https://en.wikipedia.org/wiki/Unsupervised_learning",
    "https://en.wikipedia.org/wiki/Reinforcement_learning",
    "https://en.wikipedia.org/wiki/Support_vector_machine",
    "https://en.wikipedia.org/wiki/Artificial_neural_network",
    "https://en.wikipedia.org/wiki/Random_forest",
    "https://en.wikipedia.org/wiki/K-means_clustering",
    "https://en.wikipedia.org/wiki/DBSCAN",
    "https://en.wikipedia.org/wiki/Backpropagation",
    "https://en.wikipedia.org/wiki/Cross-validation_(statistics)",
    "https://en.wikipedia.org/wiki/Gradient_descent",
    "https://en.wikipedia.org/wiki/Long_short-term_memory",
]

# %%
visited = set()
crawled_data = []
max_total_pages = 2500

# %%
for url in seeds:
    if len(visited) >= max_total_pages:
        break
    remaining = max_total_pages - len(visited)
    pages, visited = crawl(url, max_depth=1, max_pages=remaining, delay=1.0, visited=visited)
    crawled_data.extend(pages)
# Out:
# Crawling: https://en.wikipedia.org/wiki/Machine_learning (depth 0)
# Crawling: https://en.wikipedia.org/wiki/Main_Page (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Machine_Learning_(journal) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Statistical_learning_in_language_acquisition (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Data_mining (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Supervised_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Unsupervised_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Semi-supervised_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Self-supervised_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Reinforcement_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Meta-learning_(computer_science) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Online_machine_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Batch_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Curriculum_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Rule-based_machine_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Neuro-symbolic_AI (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Neuromorphic_engineering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Quantum_machine_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Statistical_classification (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Generative_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Regression_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Cluster_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Dimensionality_reduction (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Density_estimation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Anomaly_detection (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Data_cleaning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Automated_machine_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Association_rule_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Semantic_analysis_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Structured_prediction (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Feature_engineering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Feature_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Learning_to_rank (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Grammar_induction (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ontology_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multimodal_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Apprenticeship_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Decision_tree_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ensemble_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bootstrap_aggregating (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Boosting_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Random_forest (depth 1)
# Crawling: https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Linear_regression (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Naive_Bayes_classifier (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_neural_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Logistic_regression (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Perceptron (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Relevance_vector_machine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Support_vector_machine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/BIRCH (depth 1)
# Crawling: https://en.wikipedia.org/wiki/CURE_algorithm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hierarchical_clustering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/K-means_clustering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Fuzzy_clustering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Expectation%E2%80%93maximization_algorithm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/DBSCAN (depth 1)
# Crawling: https://en.wikipedia.org/wiki/OPTICS_algorithm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mean_shift (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Factor_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Canonical_correlation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Independent_component_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Linear_discriminant_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Non-negative_matrix_factorization (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Principal_component_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Proper_generalized_decomposition (depth 1)
# Crawling: https://en.wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sparse_dictionary_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Graphical_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bayesian_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Conditional_random_field (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hidden_Markov_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Random_sample_consensus (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Local_outlier_factor (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Isolation_forest (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Autoencoder (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Deep_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Feedforward_neural_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Recurrent_neural_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Long_short-term_memory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Gated_recurrent_unit (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Echo_state_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Reservoir_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Boltzmann_machine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Restricted_Boltzmann_machine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Generative_adversarial_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Diffusion_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Self-organizing_map (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Convolutional_neural_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/U-Net (depth 1)
# Crawling: https://en.wikipedia.org/wiki/LeNet (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AlexNet (depth 1)
# Crawling: https://en.wikipedia.org/wiki/DeepDream (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Neural_radiance_field (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Transformer_(machine_learning_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Vision_transformer (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mamba_(deep_learning_architecture) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Spiking_neural_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Memtransistor (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Electrochemical_RAM (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Q-learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/State%E2%80%93action%E2%80%93reward%E2%80%93state%E2%80%93action (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Temporal_difference_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multi-agent_reinforcement_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Self-play_(reinforcement_learning_technique) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Active_learning_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Crowdsourcing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Human-in-the-loop (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mechanistic_interpretability (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Reinforcement_learning_from_human_feedback (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Coefficient_of_determination (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Confusion_matrix (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Learning_curve_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Receiver_operating_characteristic (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Kernel_machines (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bias%E2%80%93variance_tradeoff (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_learning_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Empirical_risk_minimization (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Occam_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Probably_approximately_correct_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Statistical_learning_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Vapnik%E2%80%93Chervonenkis_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Topological_deep_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ECML_PKDD (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Conference_on_Neural_Information_Processing_Systems (depth 1)
# Crawling: https://en.wikipedia.org/wiki/International_Conference_on_Machine_Learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/International_Conference_on_Learning_Representations (depth 1)
# Crawling: https://en.wikipedia.org/wiki/International_Joint_Conference_on_Artificial_Intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Journal_of_Machine_Learning_Research (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Glossary_of_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/List_of_datasets_for_machine-learning_research (depth 1)
# Crawling: https://en.wikipedia.org/wiki/List_of_datasets_in_computer_vision_and_image_processing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Outline_of_machine_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Template_talk:Machine_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_general_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Intelligent_agent (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Recursive_self-improvement (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Automated_planning_and_scheduling (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_vision (depth 1)
# Crawling: https://en.wikipedia.org/wiki/General_game_playing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Knowledge_representation_and_reasoning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Natural_language_processing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Robotics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AI_safety (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Symbolic_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Evolutionary_algorithm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hybrid_intelligent_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_intelligence_systems_integration (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Applications_of_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Machine_learning_in_bioinformatics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Deepfake (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Machine_learning_in_earth_sciences (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Generative_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_intelligence_art (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Generative_audio (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Music_and_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_intelligence_in_government (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_intelligence_in_healthcare (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_intelligence_in_mental_health (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_intelligence_in_industry (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Machine_translation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_intelligence_arms_race (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Machine_learning_in_physics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/List_of_artificial_intelligence_projects (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Philosophy_of_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_consciousness (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Chinese_room (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Friendly_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AI_control_problem (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AI_takeover (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ethics_of_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Existential_risk_from_artificial_general_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Turing_test (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Uncanny_valley (depth 1)
# Crawling: https://en.wikipedia.org/wiki/History_of_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Timeline_of_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Progress_in_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AI_winter (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AI_boom (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Template_talk:Artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Field_of_study (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_statistics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Data (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Generalise (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Task_(computing) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Machine_code (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Neural_network_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Speech_recognition (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Email_filtering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Agriculture (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Medicine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Predictive_analytics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Statistics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mathematical_optimisation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Exploratory_data_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Timeline_of_machine_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Arthur_Samuel_(computer_scientist) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/IBM (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_gaming (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_program (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Canadians (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Donald_O._Hebb (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Organization_of_Behavior (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hebbian_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Nerve_cells (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Neuron (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_neuron (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Cognitive_systems_engineering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Walter_Pitts (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Warren_Sturgis_McCulloch (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Algorithm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Punched_tape (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Raytheon_Company (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sonar (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Electrocardiography (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Goof (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Tom_M._Mitchell (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Operational_definition (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Alan_Turing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computing_Machinery_and_Intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Discipline_(academia) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ADALINE (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Generalised_linear_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Probabilistic_reasoning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Automated_medical_diagnosis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Symbolic_AI (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Expert_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Inductive_logic_programming (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Pattern_recognition (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Information_retrieval (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_science (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Connectionism (depth 1)
# Crawling: https://en.wikipedia.org/wiki/John_Hopfield (depth 1)
# Crawling: https://en.wikipedia.org/wiki/David_Rumelhart (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Geoffrey_Hinton (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Backpropagation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Fuzzy_logic (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Probability_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Data_compression (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Posterior_probabilities (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Arithmetic_coding (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Feature_space_vector (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AIXI (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hutter_Prize (depth 1)
# Crawling: https://en.wikipedia.org/wiki/NVIDIA_Maxine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/OpenCV (depth 1)
# Crawling: https://en.wikipedia.org/wiki/TensorFlow (depth 1)
# Crawling: https://en.wikipedia.org/wiki/MATLAB (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Unsupervised_machine_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Image_compression (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Centroid (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Image_processing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Signal_processing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Large_language_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/DeepMind (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Portable_Network_Graphics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Free_Lossless_Audio_Codec (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Discovery_(observation) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Knowledge_discovery (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Optimisation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Loss_function (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Labeled_data (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Statistical_inference (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sample_(statistics) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Michael_I._Jordan (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Data_science (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Leo_Breiman (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Deep_neural_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Medical_diagnostics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Theoretical_computer_science (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bias%E2%80%93variance_decomposition (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Errors_and_residuals (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Overfitting (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Time_complexity (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Map_(mathematics) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Autonomous_car (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Support-vector_machine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Linear_classifier (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Training_data (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Array_data_structure (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Feature_vector (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Matrix_(mathematics) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mathematical_optimization (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Similarity_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ranking (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Recommender_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Weak_supervision (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_agent (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Action_selection (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Game_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Control_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Operations_research (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Information_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Simulation-based_optimisation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multi-agent_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Swarm_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Genetic_algorithm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Markov_decision_process (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Dynamic_programming (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Feature_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Feature_extraction (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Manifold_hypothesis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Manifold (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Manifold_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Manifold_regularisation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Topic_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multilayer_perceptron (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Dictionary_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Matrix_decomposition (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sparse_coding (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multilinear_subspace_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Tensor (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Basis_function (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sparse_matrix (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Strongly_NP-hard (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Heuristic (depth 1)
# Crawling: https://en.wikipedia.org/wiki/K-SVD (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Image_de-noising (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bank_fraud (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Outlier (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Robot_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Learning_classifier_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_immune_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Rakesh_Agrawal_(computer_scientist) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Tomasz_Imieli%C5%84ski (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Point-of-sale (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Pricing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Product_placement (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Market_basket_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Web_usage_mining (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Intrusion_detection (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Continuous_production (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bioinformatics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sequence_mining (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Piecewise (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Logic_programming (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Entailment (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Inductive_programming (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Functional_programming (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Gordon_Plotkin (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ehud_Shapiro (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Inductive_reasoning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mathematical_induction (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mathematical_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Model_selection (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Brain (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Biological_neural_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Synapse (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Real_number (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Weight_(mathematics) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Human_brain (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Biology (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Social_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Medical_diagnosis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Titanic (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Decision_tree (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Predictive_modeling (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Leaf_node (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Logical_conjunction (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Real_numbers (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Decision_making (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Tree-based_models (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Probabilistic_classification (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Binary_classifier (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Platt_scaling (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Kernel_trick (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ordinary_least_squares (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Regularization_(mathematics) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ridge_regression (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Polynomial_regression (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Kernel_regression (depth 1)
# Crawling: https://en.wikipedia.org/wiki/General_linear_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multidimensional_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Random_variables (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Conditional_independence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Directed_acyclic_graph (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bayesian_inference (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Peptide_sequence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Dynamic_Bayesian_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Influence_diagram (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Gaussian_processes (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Stochastic_process (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multivariate_normal_distribution (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Covariance_function (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bayesian_optimisation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hyperparameter_optimisation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Search_algorithm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Heuristic_(computer_science) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Natural_selection (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mutation_(genetic_algorithm) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Crossover_(genetic_algorithm) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Chromosome_(genetic_algorithm) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Dempster%E2%80%93Shafer_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Probability (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Possibility_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Imprecise_probability (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Probability_mass_function (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Uncertainty_quantification (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ensemble_methods (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Decision_boundary (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Corpus_of_text (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sensor (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Algorithmic_bias (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Federated_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Distributed_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Gboard (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Google (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Precision_agriculture (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_anatomy (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Adaptive_website (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Affective_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Astroinformatics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Automated_decision-making (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Banking (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Behaviorism (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Brain%E2%80%93computer_interface (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Cheminformatics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Citizen_Science (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Climate_Science (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Network_simulation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Credit-card_fraud (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Data_quality (depth 1)
# Crawling: https://en.wikipedia.org/wiki/DNA_sequence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_economics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Financial_market (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Handwriting_recognition (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Insurance (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Internet_fraud (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Knowledge_graph_embedding (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_linguistics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Machine_learning_control (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Machine_perception (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Material_Engineering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Marketing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Natural-language_understanding (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Online_advertising (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Robot_locomotion (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Search_engines (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sentiment_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_engineering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Structural_health_monitoring (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Syntactic_pattern_recognition (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Telecommunications (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Automated_theorem_proving (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Time_series (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Tomographic_reconstruction (depth 1)
# Crawling: https://en.wikipedia.org/wiki/User_behaviour_analytics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Netflix (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Netflix_Prize (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AT%26T_Labs (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ensemble_Averaging (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sun_Microsystems (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Vinod_Khosla (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Springer_Nature (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Black_box (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Uber (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Watson_(computer) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bing_Chat (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Explainable_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Adversarial_machine_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Backdoor_(computing) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Algorithmic_transparency (depth 1)
# Crawling: https://en.wikipedia.org/wiki/White-box_testing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Test_set (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Cross-validation_(statistics) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bootstrapping_(statistics) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sensitivity_and_specificity (depth 1)
# Crawling: https://en.wikipedia.org/wiki/False_positive_rate (depth 1)
# Crawling: https://en.wikipedia.org/wiki/False_negative_rate (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ethics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Fairness_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Accountability (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Privacy (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Regulation_of_artificial_intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Machine_ethics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Lethal_autonomous_weapon (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AI_alignment (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Technological_unemployment (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Misinformation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Moral_status (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_superintelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Commission_for_Racial_Equality (depth 1)
# Crawling: https://en.wikipedia.org/wiki/St_George%27s,_University_of_London (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Geolitica (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Data_collection (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Text_corpus (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Tay_(chatbot) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Chatbot (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ProPublica (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Investigative_journalism (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Fei-Fei_Li (depth 1)
# Crawling: https://en.wikipedia.org/wiki/GPU (depth 1)
# Crawling: https://en.wikipedia.org/wiki/OpenAI (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AlphaZero (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Tensor_Processing_Unit (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Graphics_processing_unit (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Field-programmable_gate_array (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Neuromorphic_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Physical_neural_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Chemical_synapse (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Embedded_systems (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Wearable_computer (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Edge_device (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Microcontrollers (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hardware_acceleration (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Approximate_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Pruning_(artificial_neural_network) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Knowledge_distillation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_suite (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Caffe_(software) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Deeplearning4j (depth 1)
# Crawling: https://en.wikipedia.org/wiki/DeepSpeed (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ELKI (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Google_JAX (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Infer.NET (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Keras (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Kubeflow (depth 1)
# Crawling: https://en.wikipedia.org/wiki/LightGBM (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Apache_Mahout (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mallet_(software_project) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Microsoft_Cognitive_Toolkit (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ML.NET (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mlpack (depth 1)
# Crawling: https://en.wikipedia.org/wiki/MXNet (depth 1)
# Crawling: https://en.wikipedia.org/wiki/OpenNN (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Orange_(software) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Pandas_(software) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ROOT (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Scikit-learn (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Shogun_(toolbox) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Apache_Spark (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Apache_SystemML (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Torch_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/PyTorch (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Weka_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/MOA_(Massive_Online_Analysis) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/XGBoost (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Yooreeka (depth 1)
# Crawling: https://en.wikipedia.org/wiki/KNIME (depth 1)
# Crawling: https://en.wikipedia.org/wiki/RapidMiner (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Amazon_Machine_Learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Angoss (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Azure_Machine_Learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/IBM_Watson_Studio (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Google_Cloud_Platform (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Google_APIs (depth 1)
# Crawling: https://en.wikipedia.org/wiki/SPSS_Modeler (depth 1)
# Crawling: https://en.wikipedia.org/wiki/KXEN_Inc. (depth 1)
# Crawling: https://en.wikipedia.org/wiki/LIONsolver (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mathematica (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Neural_Designer (depth 1)
# Crawling: https://en.wikipedia.org/wiki/NeuroSolutions (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Oracle_Data_Mining (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Oracle_Cloud (depth 1)
# Crawling: https://en.wikipedia.org/wiki/PolyAnalyst (depth 1)
# Crawling: https://en.wikipedia.org/wiki/RCASE (depth 1)
# Crawling: https://en.wikipedia.org/wiki/SAS_(software) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/SequenceL (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Splunk (depth 1)
# Crawling: https://en.wikipedia.org/wiki/STATISTICA (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Nature_Machine_Intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Neural_Computation_(journal) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/IEEE_Transactions_on_Pattern_Analysis_and_Machine_Intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AAAI_Conference_on_Artificial_Intelligence (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Association_for_Computational_Linguistics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/European_Conference_on_Machine_Learning_and_Principles_and_Practice_of_Knowledge_Discovery_in_Databases (depth 1)
# Crawling: https://en.wikipedia.org/wiki/International_Conference_on_Computational_Intelligence_Methods_for_Bioinformatics_and_Biostatistics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/International_Conference_on_Intelligent_Robots_and_Systems (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Conference_on_Knowledge_Discovery_and_Data_Mining (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Big_data (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Differentiable_programming (depth 1)
# Crawling: https://en.wikipedia.org/wiki/M-theory_(learning_framework) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Machine_unlearning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Solomonoff%27s_theory_of_inductive_inference (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Paraphrase (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Doi_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ISBN_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ISSN_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/S2CID_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bibcode_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/PMC_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/PMID_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Christopher_M._Bishop (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Jerome_H._Friedman (depth 1)
# Crawling: https://en.wikipedia.org/wiki/CiteSeerX_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/JSTOR_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Time_(magazine) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Wayback_Machine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Stevan_Harnad (depth 1)
# Crawling: https://en.wikipedia.org/wiki/OCLC_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Stuart_J._Russell (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Peter_Norvig (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Artificial_Intelligence:_A_Modern_Approach (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Carla_Brodley (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ArXiv_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Naomi_Altman (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Nature_Methods (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Physical_Review_E (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mehryar_Mohri (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Institute_of_Electrical_and_Electronics_Engineers (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Springer_Science%2BBusiness_Media (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Yoshua_Bengio (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Michal_Aharon (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ACM_Computing_Surveys (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Corinna_Cortes (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Chartered_Financial_Analyst_(CFA) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/The_Wall_Street_Journal (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ArXiv (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hdl_(identifier) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/I_(British_newspaper) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/The_Register (depth 1)
# Crawling: https://en.wikipedia.org/wiki/IEEE_Spectrum (depth 1)
# Crawling: https://en.wikipedia.org/wiki/New_York_Times (depth 1)
# Crawling: https://en.wikipedia.org/wiki/New_England_Journal_of_Medicine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Harvard_University (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Pedro_Domingos (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Nils_Nilsson_(researcher) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Alan_Mackworth (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Christopher_Bishop (depth 1)
# Crawling: https://en.wikipedia.org/wiki/The_Master_Algorithm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Richard_O._Duda (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Peter_E._Hart (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Trevor_Hastie (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Robert_Tibshirani (depth 1)
# Crawling: https://en.wikipedia.org/wiki/David_J._C._MacKay (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ray_Solomonoff (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Dartmouth_workshop (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Template_talk:Artificial_intelligence_navbox (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Parameter (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hyperparameter_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Loss_functions_for_classification (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Double_descent (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Gradient_descent (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Stochastic_gradient_descent (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Quasi-Newton_method (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Conjugate_gradient_method (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Attention_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Convolution (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Normalization_(machine_learning) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Batch_normalization (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Activation_function (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Softmax_function (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sigmoid_function (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Rectifier_(neural_networks) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Gating_mechanism (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Weight_initialization (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Training,_validation,_and_test_data_sets (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Data_augmentation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Prompt_engineering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Imitation_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Policy_gradient_method (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Diffusion_process (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Latent_diffusion_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Autoregressive_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Retrieval-augmented_generation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Word_embedding (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hallucination_(artificial_intelligence) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Language_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Neural_machine_translation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/WaveNet (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Human_image_synthesis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Optical_character_recognition (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Deep_learning_speech_synthesis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/15.ai (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ElevenLabs (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Whisper_(speech_recognition_system) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Facial_recognition_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AlphaFold (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Text-to-image_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Aurora_(text-to-image_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/DALL-E (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Adobe_Firefly (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Flux_(text-to-image_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ideogram_(text-to-image_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Imagen_(text-to-image_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Midjourney (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Stable_Diffusion (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Text-to-video_model (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Dream_Machine_(text-to-video_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Runway_(company) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/MiniMax_(company) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Kling_(text-to-video_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Sora_(text-to-video_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Google_DeepMind (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Suno_AI (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Udio (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Word2vec (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Seq2seq (depth 1)
# Crawling: https://en.wikipedia.org/wiki/GloVe (depth 1)
# Crawling: https://en.wikipedia.org/wiki/BERT_(language_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/T5_(language_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Llama_(language_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Chinchilla_(language_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/PaLM (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Generative_pre-trained_transformer (depth 1)
# Crawling: https://en.wikipedia.org/wiki/GPT-1 (depth 1)
# Crawling: https://en.wikipedia.org/wiki/GPT-2 (depth 1)
# Crawling: https://en.wikipedia.org/wiki/GPT-3 (depth 1)
# Crawling: https://en.wikipedia.org/wiki/GPT-J (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ChatGPT (depth 1)
# Crawling: https://en.wikipedia.org/wiki/GPT-4 (depth 1)
# Crawling: https://en.wikipedia.org/wiki/GPT-4o (depth 1)
# Crawling: https://en.wikipedia.org/wiki/OpenAI_o1 (depth 1)
# Crawling: https://en.wikipedia.org/wiki/OpenAI_o3 (depth 1)
# Crawling: https://en.wikipedia.org/wiki/GPT-4.5 (depth 1)
# Crawling: https://en.wikipedia.org/wiki/GPT-4.1 (depth 1)
# Crawling: https://en.wikipedia.org/wiki/OpenAI_o4-mini (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Claude_(language_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Gemini_(language_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Gemini_(chatbot) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Grok_(chatbot) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/LaMDA (depth 1)
# Crawling: https://en.wikipedia.org/wiki/BLOOM_(language_model) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Project_Debater (depth 1)
# Crawling: https://en.wikipedia.org/wiki/IBM_Watson (depth 1)
# Crawling: https://en.wikipedia.org/wiki/IBM_Watsonx (depth 1)
# Crawling: https://en.wikipedia.org/wiki/IBM_Granite (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Huawei_PanGu (depth 1)
# Crawling: https://en.wikipedia.org/wiki/DeepSeek_(chatbot) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Qwen (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AlphaGo (depth 1)
# Crawling: https://en.wikipedia.org/wiki/OpenAI_Five (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Self-driving_car (depth 1)
# Crawling: https://en.wikipedia.org/wiki/MuZero (depth 1)
# Crawling: https://en.wikipedia.org/wiki/AutoGPT (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Robot_control (depth 1)
# Crawling: https://en.wikipedia.org/wiki/John_von_Neumann (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Claude_Shannon (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Marvin_Minsky (depth 1)
# Crawling: https://en.wikipedia.org/wiki/John_McCarthy_(computer_scientist) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Nathaniel_Rochester_(computer_scientist) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Allen_Newell (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Cliff_Shaw (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Herbert_A._Simon (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Oliver_Selfridge (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Frank_Rosenblatt (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Bernard_Widrow (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Joseph_Weizenbaum (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Seymour_Papert (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Seppo_Linnainmaa (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Paul_Werbos (depth 1)
# Crawling: https://en.wikipedia.org/wiki/J%C3%BCrgen_Schmidhuber (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Yann_LeCun (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Lotfi_A._Zadeh (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Stephen_Grossberg (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Alex_Graves_(computer_scientist) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Andrew_Ng (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Alex_Krizhevsky (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ilya_Sutskever (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Demis_Hassabis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/David_Silver_(computer_scientist) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ian_Goodfellow (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Andrej_Karpathy (depth 1)
# Crawling: https://en.wikipedia.org/wiki/James_Goodnight (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Neural_Turing_machine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Differentiable_neural_computer (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Transformer_(deep_learning_architecture) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Residual_neural_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Highway_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Variational_autoencoder (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Graph_neural_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/List_of_artificial_intelligence_companies (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Template_talk:Computer_science (depth 1)
# Crawling: https://en.wikipedia.org/wiki/ACM_Computing_Classification_System (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_hardware (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Printed_circuit_board (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Peripheral (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Integrated_circuit (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Very_Large_Scale_Integration (depth 1)
# Crawling: https://en.wikipedia.org/wiki/System_on_a_chip (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Green_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Electronic_design_automation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Processor_(computing) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/List_of_computer_size_categories (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Form_factor_(design) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_architecture (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_complexity (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Dependability (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Embedded_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Real-time_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_network (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Network_architecture (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Network_protocol (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Networking_hardware (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Network_scheduler (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Network_performance (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Network_service (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Interpreter_(computing) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Middleware (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Virtual_machine (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Operating_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_quality (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Programming_language_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Programming_tool (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Programming_paradigm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Programming_language (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Compiler_construction (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Domain-specific_language (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Modeling_language (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_framework (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Integrated_development_environment (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_configuration_management (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Library_(computing) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_repository (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_development (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Control_variable_(programming) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_development_process (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Requirements_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_design (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_construction (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_deployment (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Software_maintenance (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Programming_team (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Open-source_software (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Theory_of_computation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Model_of_computation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Stochastic_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Formal_language (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Automata_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computability_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_complexity_theory (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Logic_in_computer_science (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Semantics_(computer_science) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Algorithm_design (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Analysis_of_algorithms (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Algorithmic_efficiency (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Randomized_algorithm (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_geometry (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Discrete_mathematics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mathematical_software (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Mathematical_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Numerical_analysis (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Information_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Database (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_data_storage (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Enterprise_information_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Social_software (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Geographic_information_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Decision_support_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Process_control (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multimedia_database (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Digital_library (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computing_platform (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Digital_marketing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/World_Wide_Web (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_security (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Cryptography (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Formal_methods (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Security_hacker (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Security_service_(telecommunication) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Intrusion_detection_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Hardware_security (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Network_security (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Information_security (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Application_security (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Human%E2%80%93computer_interaction (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Interaction_design (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Augmented_reality (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Virtual_reality (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Social_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Ubiquitous_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Visualization_(graphics) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_accessibility (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Concurrency_(computer_science) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Concurrent_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Parallel_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Distributed_computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multithreading_(computer_architecture) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multiprocessing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Multi-task_learning (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_graphics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computer_animation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Rendering_(computer_graphics) (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Photograph_manipulation (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Solid_modeling (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Quantum_Computing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/E-commerce (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Enterprise_software (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_mathematics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_physics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_chemistry (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_biology (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_social_science (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Computational_engineering (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Health_informatics (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Digital_art (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Electronic_publishing (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Cyberwarfare (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Electronic_voting (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Video_game (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Word_processor (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Educational_technology (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Document_management_system (depth 1)
# Crawling: https://en.wikipedia.org/wiki/Outline_of_computer_science (depth 1)

# %%
with open("crawled_data.json", "w", encoding="utf-8") as f:
    json.dump(crawled_data, f, indent=2, ensure_ascii=False)

# %% [markdown]
# #Preprocess and Embed

# %%
with open("crawled_data.json", "r", encoding="utf-8") as f:
    crawled_data = json.load(f)

# %%
texts = [entry["text"] for entry in crawled_data]
urls = [entry["url"] for entry in crawled_data]
metadata = [entry for entry in crawled_data]

embedder = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
embeddings = embedder.encode(texts, convert_to_tensor=True).cpu().numpy()

index = faiss.IndexFlatL2(embeddings.shape[1])
index.add(embeddings)

# %%
# Flan-T5 model, MAKE SURE USING T4 GPU RUNTIME!!!!!
device = 0 if torch.cuda.is_available() else -1
tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-base")
gen_model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base").to(device)
tokenizer.truncation_side = "left"
generator = pipeline("text2text-generation", model=gen_model, tokenizer=tokenizer, device=device, max_length=300, do_sample=False)
# Out:
# Device set to use cuda:0

# %%
# Query Expansion
def expand_query(query, top_k=3, max_terms=200):
    q_vec = embedder.encode([query], convert_to_tensor=True).cpu().numpy()
    _, idxs = index.search(q_vec, top_k)
    terms = []
    for i in idxs[0]:
        terms.extend(texts[i].split()[:max_terms // top_k])
    return f"{query} {' '.join(terms)}"

# %%
# Question Answering
def answer_question(query, top_k=3, max_context_chars=4000, sim_threshold=0.3):
    expanded = expand_query(query, top_k=top_k)
    q_vec = embedder.encode([expanded], convert_to_tensor=True).cpu().numpy()
    dists, idxs = index.search(q_vec, top_k)
    avg_dist = np.mean(dists[0])
    if avg_dist < 1.0:
        per = max_context_chars // top_k
        snippets = []
        for i in idxs[0]:
            chunk = texts[i][:per]
            chunk = chunk.rsplit(" ", 1)[0]
            snippets.append(chunk.strip() + " ")
        context = "\n\n".join(snippets)
        raw = generator(f"You are a helpful assistant.\n\n{context}\n\nQuestion: {query}\nAnswer:\n")[0]["generated_text"].strip()
        clean = generator(f"Rewrite with perfect spacing and punctuation:\n\n{raw}\n")[0]["generated_text"].strip()
        return demash_text(clean)
    else:
        return f"(Low similarity - avg distance {avg_dist:.4f}) I'm not confident I can answer that based on the available information."

# %%
# Relevance scoring utility
def get_relevance_scores(query, top_k=5):
    q_vec = embedder.encode([query], convert_to_tensor=True).cpu().numpy()
    sims, idxs = index.search(q_vec, top_k)
    return [(urls[i], float(1 - sims[0][j])) for j, i in enumerate(idxs[0])]

# %% [markdown]
# #Question and Answering

# %%
questions = [
    "What is machine learning?",
    "What is deep learning?",
    "What is supervised learning?",
    "What is unsupervised learning?",
    "What is reinforcement learning?",
    "What is a support vector machine?",
    "What is an artificial neural network?",
    "What is the difference between classification and regression?",
    "What is overfitting in machine learning?",
    "What is underfitting?",
    "What is a training set and a test set?",
    "What does it mean to train a model?",
    "What is a feature in machine learning?",
    "What is feature engineering?",
    "What is feature selection?",
    "What is dimensionality reduction?",
    "What is principal component analysis?",
    "What is clustering?",
    "How does k-means clustering work?",
    "What is DBSCAN?",
    "What is a decision tree?",
    "What is an ensemble method?",
    "What is random forest?",
    "What is boosting in machine learning?",
    "What is bagging?",
    "What is logistic regression used for?",
    "What is a confusion matrix?",
    "What is precision and recall?",
    "What is a learning curve?",
    "What is cross-validation?",
]

# %%
for q in questions:
    print("Q:", q)
    print("A:", answer_question(q))
    print("\nTop 3 relevant documents and scores:")
    for url, score in get_relevance_scores(q, top_k=3):
        print(f"- {url} (score: {score:.4f})")
    print("-" * 60)
# Out:
# Q: What is machine learning?
# A: ability of a machine to learn and then mimic human behavior that requires intelligence.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Theoretical_computer_science (score: 0.7113)
# - https://en.wikipedia.org/wiki/Predictive_analytics (score: 0.6256)
# - https://en.wikipedia.org/wiki/Machine_learning (score: 0.6151)
# ------------------------------------------------------------
# Q: What is deep learning?
# A: a class of machine learning algorithms in which a hierarchy of layers is used to transform input data into a progressively more abstract and composite representation.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Artificial_intelligence_in_mental_health (score: 0.6380)
# - https://en.wikipedia.org/wiki/Deep_learning (score: 0.6205)
# - https://en.wikipedia.org/wiki/Deep_neural_network (score: 0.6205)
# ------------------------------------------------------------
# Q: What is supervised learning?
# A: a type of algorithm that learns from labeled data and learns how to assign labels to future data that is unlabeled.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Computational_biology (score: 0.5974)
# - https://en.wikipedia.org/wiki/Online_machine_learning (score: 0.5128)
# - https://en.wikipedia.org/wiki/Batch_learning (score: 0.5128)
# ------------------------------------------------------------
# Q: What is unsupervised learning?
# A: a type of algorithm that finds patterns in unlabeled data.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Machine_learning (score: 0.4980)
# - https://en.wikipedia.org/wiki/Computational_biology (score: 0.4487)
# - https://en.wikipedia.org/wiki/Artificial_intelligence (score: 0.4473)
# ------------------------------------------------------------
# Q: What is reinforcement learning?
# A: an interdisciplinary area of machine learning and optimal control concerned with how an intelligent agent should take actions in a dynamic environment in order to maximize a reward signal.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Q-learning (score: 0.5546)
# - https://en.wikipedia.org/wiki/Machine_learning (score: 0.5469)
# - https://en.wikipedia.org/wiki/Reinforcement_learning (score: 0.5169)
# ------------------------------------------------------------
# Q: What is a support vector machine?
# A: a set of related supervised learning methods used for classification and regression.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Support_vector_machine (score: 0.7041)
# - https://en.wikipedia.org/wiki/Support-vector_machine (score: 0.7041)
# - https://en.wikipedia.org/wiki/Machine_learning (score: 0.6197)
# ------------------------------------------------------------
# Q: What is an artificial neural network?
# A: a deep learning model structure which aims to mimic a human brain.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Artificial_intelligence (score: 0.6598)
# - https://en.wikipedia.org/wiki/Recommender_system (score: 0.5563)
# - https://en.wikipedia.org/wiki/Recurrent_neural_network (score: 0.5491)
# ------------------------------------------------------------
# Q: What is the difference between classification and regression?
# A: Classification is very common for machine learning applications.. In facial recognition, for instance, a picture of a person's face would be the input, and the output label would be that person's name..
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Machine_learning (score: 0.2797)
# - https://en.wikipedia.org/wiki/Statistical_learning_theory (score: 0.2180)
# - https://en.wikipedia.org/wiki/Statistical_learning_theory (score: 0.1956)
# ------------------------------------------------------------
# Q: What is overfitting in machine learning?
# A: the production of an analysis that corresponds too closely or exactly to a particular set of data, and may therefore fail to fit to additional data or predict future observations reliably.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Overfitting (score: 0.6291)
# - https://en.wikipedia.org/wiki/Overfitting (score: 0.5076)
# - https://en.wikipedia.org/wiki/Overfitting (score: 0.5022)
# ------------------------------------------------------------
# Q: What is underfitting?
# A: the statistical model or machine learning algorithm is too simplistic to accurately capture the patterns in the data.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Overfitting (score: 0.5823)
# - https://en.wikipedia.org/wiki/Overfitting (score: 0.4322)
# - https://en.wikipedia.org/wiki/Overfitting (score: 0.3627)
# ------------------------------------------------------------
# Q: What is a training set and a test set?
# A: data set :
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Training_data (score: 0.4402)
# - https://en.wikipedia.org/wiki/Test_set (score: 0.4402)
# - https://en.wikipedia.org/wiki/Training,_validation,_and_test_data_sets (score: 0.4402)
# ------------------------------------------------------------
# Q: What does it mean to train a model?
# A: presenting it with ...
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Diffusion_model (score: 0.3050)
# - https://en.wikipedia.org/wiki/Large_language_model (score: 0.1252)
# - https://en.wikipedia.org/wiki/T5_(language_model) (score: 0.1059)
# ------------------------------------------------------------
# Q: What is a feature in machine learning?
# A: an individual measurable property or characteristic of a data set.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Feature_space_vector (score: 0.5587)
# - https://en.wikipedia.org/wiki/Feature_vector (score: 0.5587)
# - https://en.wikipedia.org/wiki/Feature_(machine_learning) (score: 0.5587)
# ------------------------------------------------------------
# Q: What is feature engineering?
# A: Selecting and designing good features is an important area in machine learning, which is called feature .
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Feature_engineering (score: 0.4691)
# - https://en.wikipedia.org/wiki/Feature_extraction (score: 0.4691)
# - https://en.wikipedia.org/wiki/Learning_to_rank (score: 0.4127)
# ------------------------------------------------------------
# Q: What is feature selection?
# A: aims to find a suitable subset of the input variables (features, or attributes) for the task at hand.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Dimensionality_reduction (score: 0.5077)
# - https://en.wikipedia.org/wiki/Feature_engineering (score: 0.4544)
# - https://en.wikipedia.org/wiki/Feature_extraction (score: 0.4544)
# ------------------------------------------------------------
# Q: What is dimensionality reduction?
# A: a process of reducing the number of random variables under consideration by obtaining a set of principal variables.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Dimensionality_reduction (score: 0.7875)
# - https://en.wikipedia.org/wiki/Machine_learning (score: 0.5826)
# - https://en.wikipedia.org/wiki/Feature_space_vector (score: 0.4871)
# ------------------------------------------------------------
# Q: What is principal component analysis?
# A: linear dimensionality reduction technique :
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Principal_component_analysis (score: 0.5787)
# - https://en.wikipedia.org/wiki/Principal_component_analysis (score: 0.4738)
# - https://en.wikipedia.org/wiki/Principal_component_analysis (score: 0.4695)
# ------------------------------------------------------------
# Q: What is clustering?
# A: data analyzing technique :
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Cluster_analysis (score: 0.6624)
# - https://en.wikipedia.org/wiki/Machine_learning_in_bioinformatics (score: 0.5997)
# - https://en.wikipedia.org/wiki/K-means_clustering (score: 0.5372)
# ------------------------------------------------------------
# Q: How does k-means clustering work?
# A: aims to partition n observations into k clusters in which each observation belongs to the cluster with the nearest mean (cluster centers or cluster centro id serving as a prototype of the cluster.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/K-means_clustering (score: 0.6220)
# - https://en.wikipedia.org/wiki/K-means_clustering (score: 0.5659)
# - https://en.wikipedia.org/wiki/Cluster_analysis (score: 0.5194)
# ------------------------------------------------------------
# Q: What is DBSCAN?
# A: algorithm :
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/DBSCAN (score: 0.4993)
# - https://en.wikipedia.org/wiki/DBSCAN (score: 0.3435)
# - https://en.wikipedia.org/wiki/DBSCAN (score: 0.3307)
# ------------------------------------------------------------
# Q: What is a decision tree?
# A: a flowchart like structure in which each internal node represents a test on an attribute e g whether a coin flip comes up heads or tails), each branch represents the outcome of the test, and each leaf node represents a class label (decision taken after computing all attributes).
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Decision_tree_learning (score: 0.6638)
# - https://en.wikipedia.org/wiki/Tree-based_models (score: 0.6638)
# - https://en.wikipedia.org/wiki/Decision_tree (score: 0.6529)
# ------------------------------------------------------------
# Q: What is an ensemble method?
# A: (4).
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Ensemble_Averaging (score: 0.4722)
# - https://en.wikipedia.org/wiki/Decision_tree_learning (score: 0.4471)
# - https://en.wikipedia.org/wiki/Tree-based_models (score: 0.4471)
# ------------------------------------------------------------
# Q: What is random forest?
# A: an ensemble learning method for classification, regression and other tasks that works by creating a multitude of decision trees during training.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Random_forest (score: 0.5258)
# - https://en.wikipedia.org/wiki/Random_forest (score: 0.5014)
# - https://en.wikipedia.org/wiki/Machine_learning_in_bioinformatics (score: 0.4731)
# ------------------------------------------------------------
# Q: What is boosting in machine learning?
# A: an ensemble meta heuristic for primarily reducing bias (as opposed to variance)
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Boosting_(machine_learning) (score: 0.6451)
# - https://en.wikipedia.org/wiki/Ensemble_learning (score: 0.4578)
# - https://en.wikipedia.org/wiki/Ensemble_methods (score: 0.4578)
# ------------------------------------------------------------
# Q: What is bagging?
# A: a machine learning (ML) ensemble meta algorithm
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Bootstrap_aggregating (score: 0.1474)
# - https://en.wikipedia.org/wiki/Random_forest (score: 0.1168)
# - https://en.wikipedia.org/wiki/Bootstrap_aggregating (score: 0.1016)
# ------------------------------------------------------------
# Q: What is logistic regression used for?
# A: binary classification tasks -
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Logistic_regression (score: 0.4923)
# - https://en.wikipedia.org/wiki/Logistic_regression (score: 0.4222)
# - https://en.wikipedia.org/wiki/Logistic_regression (score: 0.4079)
# ------------------------------------------------------------
# Q: What is a confusion matrix?
# A: table with two rows and two columns.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Confusion_matrix (score: 0.5074)
# - https://en.wikipedia.org/wiki/Fairness_(machine_learning) (score: 0.4767)
# - https://en.wikipedia.org/wiki/Confusion_matrix (score: 0.4153)
# ------------------------------------------------------------
# Q: What is precision and recall?
# A: external evaluation measures :
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Cluster_analysis (score: 0.4153)
# - https://en.wikipedia.org/wiki/Stochastic_computing (score: 0.3930)
# - https://en.wikipedia.org/wiki/Isolation_forest (score: 0.3228)
# ------------------------------------------------------------
# Q: What is a learning curve?
# A: a graphical representation that shows how a model's performance on a training set (and usually a validation set) changes with the number of training iterations (epochs) or the amount of training.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Learning_curve_(machine_learning) (score: 0.5453)
# - https://en.wikipedia.org/wiki/Learning_curve_(machine_learning) (score: 0.4225)
# - https://en.wikipedia.org/wiki/Learning_curve_(machine_learning) (score: 0.2768)
# ------------------------------------------------------------
# Q: What is cross-validation?
# A: re sampling and sample splitting methods that use different portions of the data to test and train a model on different iterations.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Cross-validation_(statistics) (score: 0.6009)
# - https://en.wikipedia.org/wiki/Cross-validation_(statistics) (score: 0.4260)
# - https://en.wikipedia.org/wiki/Cross-validation_(statistics) (score: 0.3674)
# ------------------------------------------------------------

# %%
questions = [
    # Hard questions
    "How does the bias–variance tradeoff affect model generalization?",
    "What is the Vapnik–Chervonenkis dimension and why is it important?",
    "How does t-SNE work and when should it be used?",
    "What are the differences between generative and discriminative models?",
    "How do attention mechanisms improve transformer performance compared to RNNs?"
]

# %%
for q in questions:
    print("Q:", q)
    print("A:", answer_question(q))
    print("\nTop 3 relevant documents and scores:")
    for url, score in get_relevance_scores(q, top_k=3):
        print(f"- {url} (score: {score:.4f})")
    print("-" * 60)
# Out:
# Q: How does the bias–variance tradeoff affect model generalization?
# A: Even though the bias variance decomposition does not directly apply in reinforcement learning, a similar tradeoff can also characterize generalization.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Bias%E2%80%93variance_tradeoff (score: 0.3270)
# - https://en.wikipedia.org/wiki/Bias%E2%80%93variance_decomposition (score: 0.3270)
# - https://en.wikipedia.org/wiki/Bias%E2%80%93variance_tradeoff (score: 0.2095)
# ------------------------------------------------------------
# Q: What is the Vapnik–Chervonenkis dimension and why is it important?
# A: Geometric anomalies in higher dimensions lead to the well known curse of dimensionality.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Vapnik%E2%80%93Chervonenkis_theory (score: 0.0673)
# - https://en.wikipedia.org/wiki/Interaction_design (score: 0.0511)
# - https://en.wikipedia.org/wiki/Linear_discriminant_analysis (score: 0.0085)
# ------------------------------------------------------------
# Q: How does t-SNE work and when should it be used?
# A: T distributed Stochastic Neighbor Embedding t S NE is a nonlinear dimensionality reduction technique useful for the visualization of high dimensional datasets.. It is not recommended for use in analysis such as clustering or outlier detection since it does not necessarily preserve densities or distances.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Dimensionality_reduction (score: 0.0942)
# - https://en.wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding (score: 0.0777)
# - https://en.wikipedia.org/wiki/T-distributed_stochastic_neighbor_embedding (score: 0.0350)
# ------------------------------------------------------------
# Q: What are the differences between generative and discriminative models?
# A: Generative training algorithms are often simpler and more computationally efficient than disc rim i native training algorithms.
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Generative_model (score: 0.4776)
# - https://en.wikipedia.org/wiki/Linear_classifier (score: 0.3116)
# - https://en.wikipedia.org/wiki/Generative_model (score: 0.2913)
# ------------------------------------------------------------
# Q: How do attention mechanisms improve transformer performance compared to RNNs?
# A: The use of a transformer architecture, as opposed to previous techniques involving attention augmented RN Ns provided GP T models with a more structured memory than could be achieved through recurrent mechanisms; this resulted in "robust transfer performance across diverse ...
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/GPT-1 (score: 0.3948)
# - https://en.wikipedia.org/wiki/Transformer_(machine_learning_model) (score: 0.3844)
# - https://en.wikipedia.org/wiki/Transformer_(deep_learning_architecture) (score: 0.3844)
# ------------------------------------------------------------

# %%
questions = [
    # Nonsense Question
    "How does bababooie babado dabo da booo booie?"
]

# %%
for q in questions:
    print("Q:", q)
    print("A:", answer_question(q))
    print("\nTop 3 relevant documents and scores:")
    for url, score in get_relevance_scores(q, top_k=3):
        print(f"- {url} (score: {score:.4f})")
    print("-" * 60)
# Out:
# Q: How does bababooie babado dabo da booo booie?
# A: a karaoke mini game .
#
# Top 3 relevant documents and scores:
# - https://en.wikipedia.org/wiki/Deepfake (score: -0.3134)
# - https://en.wikipedia.org/wiki/MiniMax_(company) (score: -0.4156)
# - https://en.wikipedia.org/wiki/Product_placement (score: -0.4277)
# ------------------------------------------------------------
